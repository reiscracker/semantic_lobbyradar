# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint, pformat
from bson.son import SON
import os.

# %%
# Connect to database and create variables for the collections
client = MongoClient()
db = client.lobbyradar
entities = db.entities
relations = db.relations

# Print some statistics about our database dump
print("Collections in database: " + ", ".join(db.collection_names(include_system_collections=False)))
print("Entities: %s documents" % entities.count())
print("Relations: %s documents" % relations.count())
# Out:
# Collections in database: entities, relations
# Entities: 26380 documents
# Relations: 32137 documents

# %% [markdown]
# # The entities collection

# %% [markdown]
# Für die erste Untersuchung der Collections wird das Tool Variety verwendet (https://github.com/variety/variety). Es hilft dabei, die Daten zu verstehen und einen Überblick über sie zu bekommen.

# %%
# %%!

# %%
entities_documents = entities.find().limit(10)
pprint(list(entities_documents))
# Out:
# [{u'_id': ObjectId('54bd3c748b934da06340f4c1'),
#   u'aliases': [u'DIE LINKE',
#                u'Die Linke',
#                u'Partei DIE LINKE',
#                u'DIE LINKE.',
#                u'Linkspartei',
#                u'Linkspartei.PDS',
#                u'PDS',
#                u'WASG',
#                u'Partei des Demokratischen Sozialismus',
#                u'Arbeit & soziale Gerechtigkeit \u2013 Die Wahlalternative',
#                u'Wahlalternative',
#                u'Wahlalternative Arbeit und soziale Gerechtigkeit'],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 807000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 5, 28, 18, 11, 9, 657000),
#              u'desc': u'Partei',
#              u'format': u'string',
#              u'id': u'2b1adb60a31d37cf9cc0fdccb75149456a425095c6bf5e77abac117ed1a69d0f',
#              u'key': u'partei',
#              u'updated': datetime.datetime(2015, 5, 28, 18, 11, 9, 657000),
#              u'value': u'Die Linke'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 808000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'bb4b34d6b3f916cea2ca09b7cea7842afbec6c9d303c3dc31a5823bda70658bb',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 808000),
#              u'value': {u'addr': u'Bundesgesch\xe4ftsstelle',
#                         u'city': u'Berlin',
#                         u'country': u'Deutschland',
#                         u'email': u'bundesgeschaeftsstelle@die-linke.de',
#                         u'fax': u'+493024009310',
#                         u'name': u'Partei DIE LINKE',
#                         u'postcode': u'10178',
#                         u'street': u'Kleine Alexanderstra\xdfe 28',
#                         u'tel': u'+493024009397',
#                         u'type': u'main',
#                         u'www': u'http://www.die-linke.de/'}}],
#   u'importer': u'parteien',
#   u'name': u'Die Linke',
#   u'search': [u'die linke',
#               u'partei die linke',
#               u'linkspartei',
#               u'linksparteipds',
#               u'pds',
#               u'wasg',
#               u'partei des demokratischen sozialismus',
#               u'arbeit and soziale gerechtigkeit die wahlalternative',
#               u'wahlalternative',
#               u'wahlalternative arbeit und soziale gerechtigkeit'],
#   u'slug': u'die linke',
#   u'tags': [u'partei', u'linke'],
#   u'type': u'entity',
#   u'updated': datetime.datetime(2015, 5, 28, 18, 11, 12, 646000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4c5'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'9f8cdd62674e492bfbf99f1950696edf49aec861cee09b275fc227a3dd4c0d97',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'0191e4e640931e690d1f700a4334dd24be8a57a5284883892b74f4462af77970',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': {u'addr': u'Hinter der katholischen Kirche 3',
#                         u'city': u'Berlin',
#                         u'country': u'Deutschland',
#                         u'email': u'schimmel@1219.eu',
#                         u'fax': u'+493051057785',
#                         u'name': u'1219. Deutsche Stiftung f\xfcr interreligi\xf6sen und interkulturellen Dialog e. V.',
#                         u'postcode': u'10117',
#                         u'tel': u'+493051057773',
#                         u'type': u'main',
#                         u'www': u'http://www.1219.eu'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'9e542854787df4aedf880766a9ffc0b54d8e41786b68c2c0b75194753e32813e',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': {u'addr': u'c/o Missionszentrale der Franziskaner, Albertus-Magnus-Stra\xdfe 39',
#                         u'city': u'Bonn',
#                         u'country': u'Deutschland',
#                         u'fax': u'+492289535440',
#                         u'postcode': u'53177',
#                         u'tel': u'+49228953540',
#                         u'type': u'extra'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Anzahl der Mitglieder',
#              u'format': u'number',
#              u'id': u'9cdbbfcb06b808897f3c5af9aafe49033c85baf60440c66997b50166780593c7',
#              u'key': u'members',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': 7},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Anzahl der Mitgliedsorganisationen',
#              u'format': u'number',
#              u'id': u'b8c67d92fa82d8e76483b68719e0e901146dbb9c62e45fd6b1a6035fa5eacf5d',
#              u'key': u'organisations',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': 5},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'desc': u'Beschreibungstext',
#              u'format': u'string',
#              u'id': u'6e207fedde9f80c1a5ca4934401b33bbede084ecdb5ac662d34c0c6ea334a995',
#              u'key': u'description',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 930000),
#              u'value': u'Interreligi\xf6ser und interkultureller Dialog: \n- wissenschaftliche Bearbeitung von Aspekte des Dialogs und der \nFunktion von Religion in der deutschen und europ\xe4ischen Gesellchaft; \n- Eintreten f\xfcr das Grundrecht und das universale Menschenrecht Religionsfreiheit(auchdienegativeReligionsfreiheit/Weltan- \nchauungsfreiheit); \n- Vermittlung von Kenntnissen \xfcber alle Aspekten von Religionen und \nKulturen; \n- Diskussion von Toleranz und Offenheit gegen\xfcber anderen Religionen \nund Kulturen in einer demokratischen Gesellschaft; \n- der Einsatz f\xfcr die Rechte bedrohter Kulturen und \n- die F\xf6rderung von Dialogkultur als friedensschaffende und integrative \nMa\xdfnahme.'}],
#   u'importer': u'lobbyliste',
#   u'name': u'1219. Deutsche Stiftung f\xfcr interreligi\xf6sen und interkulturellen Dialog e. V.',
#   u'search': [u'1219 deutsche stiftung fur interreligiosen und interkulturellen dialog e v'],
#   u'slug': u'1219 deutsche stiftung fur interreligiosen und interkulturellen dialog e v',
#   u'tags': [u'lobbyorganisation', u'lobbyismus'],
#   u'type': u'entity',
#   u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 525000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4c6'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 19, 9, 420000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'3dc1416e38deac59076cd3f0d4e1235de79cb530207d06c28053134cc8aa7732',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 420000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 19, 9, 420000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'65873d29bd0ab6af91ef341689d28f4f0658cc851494a0ef34cfd07dd0cf5d42',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 420000),
#              u'value': u'Gesch\xe4ftsf\xfchrer'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'1c98f43f0787b6dfcad25c38849ef3895bd26624a79c8fa9e6203c360d120fad',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'value': u'2. Vorsitzender'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Markus Hoymann',
#   u'search': [u'markus hoymann'],
#   u'slug': u'markus hoymann',
#   u'tags': [u'lobbyist', u'lobbyismus', u'executive'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 426000)},
#  {u'_id': ObjectId('54db7b5428aa80ca5d495778'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 2, 11, 15, 55, 0, 153000),
#   u'data': [{u'auto': False,
#              u'created': datetime.datetime(2015, 2, 11, 15, 55, 0, 154000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'055eac9dcb68ba2c9634117aa35a87b57f4f15b218bcd561bd0df5ee7acbe82d',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 2, 11, 15, 55, 0, 154000),
#              u'value': u'Dr.'}],
#   u'importer': None,
#   u'name': u'J\xfcrgen Amendinger',
#   u'search': [u'jurgen amendinger'],
#   u'slug': u'jurgen amendinger',
#   u'tags': [u'bank'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 2, 11, 15, 55, 0, 153000)},
#  {u'_id': ObjectId('54db7bca28aa80ca5d49577b'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 2, 11, 15, 56, 58, 75000),
#   u'data': [],
#   u'importer': None,
#   u'name': u'Lars Hille',
#   u'search': [u'lars hille'],
#   u'slug': u'lars hille',
#   u'tags': [u'bank'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 2, 11, 15, 56, 58, 75000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4c7'),
#   u'aliases': [u'Thomas Schimmel'],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'f540a4a1c55e37d25c011e49c9e896f111904b5fb62affdbabfc270257e8b23c',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'fa0bf45185f64b9f1b476df72c704b91fb1387edc07ee831ea0c04d835934a07',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 529000),
#              u'value': u'Dr.rer.pol. , Gesch\xe4ftsf\xfchrer'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Thomas M. Schimmel',
#   u'search': [u'thomas m schimmel', u'thomas schimmel'],
#   u'slug': u'thomas m schimmel',
#   u'tags': [u'lobbyist', u'lobbyismus', u'executive'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 2, 1, 20, 50, 57, 566000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4c8'),
#   u'aliases': [u'ABDA'],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 944000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'b5862b0212eb444536431dfee2c7ddc2d9ef7ba53bdb7ae9a7f8a4b5bad26e26',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'3c64470db14a0fa7fb31353ffe2f01f13423c3791f98af13025abb92f1509209',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'value': {u'addr': u'Postfach 080463',
#                         u'city': u'Berlin',
#                         u'country': u'Deutschland',
#                         u'name': u'ABDA - Bundesvereinigung Deutscher Apothekerverb\xe4nde',
#                         u'postcode': u'10004',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'a89f383c8f12ffd70b62aa0c6d277518533bd731686f076fcad648c86e087da2',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'value': {u'addr': u'J\xe4gerstra\xdfe 49/50',
#                         u'city': u'Berlin',
#                         u'country': u'Deutschland',
#                         u'email': u'abda@abda.aponet.de',
#                         u'fax': u'+493040004598',
#                         u'name': u'Hausadresse:',
#                         u'postcode': u'10117',
#                         u'tel': u'+4930400040',
#                         u'type': u'extra',
#                         u'www': u'http://www.abda.de'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'desc': u'Anzahl der Mitglieder',
#              u'format': u'number',
#              u'id': u'57dc4eb551765c3cc301dbe10ca5bcc840f17c6e5afdcaa66133d14217aa3bf5',
#              u'key': u'members',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'value': 34},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'desc': u'Beschreibungstext',
#              u'format': u'string',
#              u'id': u'9ef2689310999bf8a88f046ecec94c83d5123eba24ec99023a38b206e3ea8da2',
#              u'key': u'description',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 945000),
#              u'value': u'Wahrnehmung und F\xf6rderung der gemeinsamen Interessen der in ihr \nzusammengeschlossenen Apothekerkammern und -vereine/-verb\xe4nde, \ninsbesondere den Meinungs- und Erfahrungsaustausch zwischen den \nMitgliedsorganisationen zu vermitteln, sie zu beraten und \xfcber alle f\xfcr \ndie Apothekerschaft wichtigen Vorg\xe4nge auf dem Gebiet des Gesundheitswesens, \ndes Arzneimittelwesens und des wirtschaftlichen und sozialen \nLebens zu unterrichten, in allen Angelegenheiten von allgemeiner, \n\xfcber den Bereich einer Mitgliederorganisation hinausgehenden \nBedeutung mit Beh\xf6rden, K\xf6rperschaften, Vereinigungen, Einrichtungen \nund sonstigen Stellen, welche mit Fragen der Arzneimittelversorgung \nzu tun haben, zu verhandeln, Beziehungen zur pharmazeutischen \nWissenschaft sowie zu in- und ausl\xe4ndischen pharmazeutischen Organisationen \nzu pflegen, die Zusammengeh\xf6rigkeit der deutschen Apothekerschaft \nzu wahren und zu pflegen, auf einheitliche Grunds\xe4tze \nf\xfcr die T\xe4tigkeit der Apotheker in \xf6ffentlichen Apotheken, Krankenhausapotheken, \nHochschulen, Industrie und Beh\xf6rden, f\xfcr das Apothekerwesen \nund den Arzneimittelverkehr sowie zu den Tr\xe4gern der \nSozialversicherung hinzuwirken sowie den Deutschen Apothekertag \nvorzubereiten.'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Bundesvereinigung Deutscher Apothekerverb\xe4nde',
#   u'search': [u'bundesvereinigung deutscher apothekerverbande', u'abda'],
#   u'slug': u'bundesvereinigung deutscher apothekerverbande',
#   u'tags': [u'lobbyorganisation', u'lobbyismus', u'gesundheit', u'pharma'],
#   u'type': u'entity',
#   u'updated': datetime.datetime(2015, 7, 7, 6, 13, 19, 657000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4c9'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 528000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 19, 9, 419000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'042caeed236dd998957748e470d4f42187d921c343d692277d7aa902d2467fa7',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 419000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 19, 9, 419000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'f721aa92bf786bae28604915fb86e40198e22baa479424722b63c9146eaae127',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 419000),
#              u'value': u'Pater OFM, Pr\xe4sident'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 528000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'b2b6a5b73a3de578d533e314c585b4d7a7655040ca99be048b313fc17c541926',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 528000),
#              u'value': u'Pater OFM, 1. Vorsitzender'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Claudius Gro\xdf',
#   u'search': [u'claudius gross'],
#   u'slug': u'claudius gross',
#   u'tags': [u'lobbyist', u'lobbyismus', u'executive'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 1, 19, 17, 19, 9, 433000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4ca'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 539000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 58, 503000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'56083617cae490f72813172884f9f23718ae807f9a11100f1b196fcc26470fa1',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 58, 503000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 58, 503000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'53d8b1bd072cd593088df6d47a8e334af1e5a7ebfe22d829ce99c11dbf29ed3d',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 58, 503000),
#              u'value': u'1. Vorsitzender'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 539000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'd0bc1621c27d2c866cfda700bd099b91c1ce4d2a6f25c67b12a8cf2eba618c08',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 539000),
#              u'value': u'Apotheker Pr\xe4sidiumsmitglieder'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Fritz Becker',
#   u'search': [u'fritz becker'],
#   u'slug': u'fritz becker',
#   u'tags': [u'lobbyist', u'lobbyismus', u'executive'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 1, 19, 17, 18, 58, 515000)},
#  {u'_id': ObjectId('54bd3c768b934da06340f4cb'),
#   u'aliases': [],
#   u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 541000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 47, 722000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'487af46afc0e7dc7499f925f2e28a3af45eb7b281d153be7d4cf3a3f13c5b1eb',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 47, 722000),
#              u'value': {u'remark': u'created by lobbyliste importer',
#                         u'url': u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 47, 722000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'21b955e344c37a2556f2e59b05280f2c179910c526a3a78ce4791f0fa23dcbe2',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 47, 722000),
#              u'value': u'Pr\xe4sidiumsmitglieder'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 19, 17, 18, 46, 541000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'41618f5fc81c0f70ad2d5f510394b159a7ad7a3ee718cafafffe2237c462dedf',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 19, 17, 18, 46, 541000),
#              u'value': u'Apotheker Pr\xe4sidiumsmitglieder'}],
#   u'importer': u'lobbyliste',
#   u'name': u'Wolfgang Pfeil',
#   u'search': [u'wolfgang pfeil'],
#   u'slug': u'wolfgang pfeil',
#   u'tags': [u'lobbyist', u'lobbyismus', u'executive'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 1, 19, 17, 18, 47, 734000)}]

# %%
print("Distict entity types:" + pformat(db.entities.distinct("type")))

# %%
from bson.son import SON

# Aggregation pipeline that groups by type (entity/person) and counts the sum of documents in each group in a field "counter"
# The second step sorts the groups by counter and id 
pipeline = [
    {"$group": {"_id": "$type", "counter": {"$sum": 1}}},   # First step
    {"$sort": SON([("counter", -1), ("_id", -1)])}          # Second step
]

# Output as list to get all values at once instead of a cursor
print("Entitiy types count:")
print(list(db.entities.aggregate(pipeline, cursor={})))
print("Relation types count:")
print(list(db.relations.aggregate(pipeline, cursor={})))

# %%
# Aggregation mit Gruppierung der Dokumente aus der collection entities nach Feld "importer", zählen der Gruppen und aufsteigend danach sortieren
pipeline = [ {"$group": {"_id": "$importer", "count": {"$sum": 1}}} , {"$sort": {"count":1} }]
list(db.entities.aggregate(pipeline, cursor={}))

# %%
# Entitäten mit Attribut "importer": "parteispenden14"
query = {'type': 'entity', 'importer': 'parteispenden14'}
projection = {'_id': 0, 'name': 1}
for i in db.entities.find(query, projection):
     pprint(i)

print("%s Entitäten mit importer parteispenden14 gefunden" % db.entities.find(query, projection).count())

# %%
# Gruppierung nach importer und Zählen der Elemente der Gruppen. Dann sortieren
pipeline = [ {"$group": {"_id": "$importer", "count": {"$sum": 1}}} , {"$sort": {"count":1} }]
list(db.entities.aggregate(pipeline, cursor={}))

# %%
# Query on a array fields (here tags field)                                                                                                                                                    
query = {'tags': "representative"}                                                                                                                                                             
one_representative = db.entities.find_one(query)                                                                                                                                                                    
print("\"%s\" is a representative." % one_representative.get("name"))
one_representative.get("tags")

# %%
# in compararion with                                                                                                                                                                          
print("Die Datenbank enthält %s Entitäten mit Tag Medien und %s Entitäten mit Tag lobbyismus" % (db.entities.find({'tags': "Medien"}).count(), db.entities.find({'tags': "lobbyismus"}).count()))
