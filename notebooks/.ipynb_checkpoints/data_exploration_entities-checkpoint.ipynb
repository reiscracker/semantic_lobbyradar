# %%
import pymongo
from pymongo import MongoClient
from pprint import pprint, pformat, PrettyPrinter
from bson.son import SON
from os.path import exists
import json
from ipy_table import *

# %%
# Connect to database and create variables for the collections
client = MongoClient()
db = client.lobbyradar
entities = db.entities
relations = db.relations

# Print some statistics about our database dump
print("Collections in database: " + ", ".join(db.collection_names(include_system_collections=False)))
print("Entities: %s documents" % entities.count())
print("Relations: %s documents" % relations.count())
# Out:
# Collections in database: entities, relations
# Entities: 26380 documents
# Relations: 32137 documents

# %% [markdown]
# # The entities collection

# %% [markdown]
# Als erstes werfen wir einen Blick in das erste Dokument der Collection um eine Ahnung zu erhalten, womit wir es überhaupt zu tun haben. Die Dokumente in einer MongoDB werden im JSON-Format abgespeichert.
# Interessant sind dabei vor allem die direkten Werte des Dokuments, sodass eine Tiefe von 2 erst einmal ausreicht um einen Überblick zu bekommen (Eine vollständige Auflistung des Dokumentenobjekts ist ....... einzusehen. ).

# %%
# Get a sample document to have a look at and print it
first_entity_document = entities.find_one()
pprint(first_entity_document, depth=2)
# Out:
# {u'_id': ObjectId('54bd3c748b934da06340f4c1'),
#  u'aliases': [u'DIE LINKE',
#               u'Die Linke',
#               u'Partei DIE LINKE',
#               u'DIE LINKE.',
#               u'Linkspartei',
#               u'Linkspartei.PDS',
#               u'PDS',
#               u'WASG',
#               u'Partei des Demokratischen Sozialismus',
#               u'Arbeit & soziale Gerechtigkeit \u2013 Die Wahlalternative',
#               u'Wahlalternative',
#               u'Wahlalternative Arbeit und soziale Gerechtigkeit'],
#  u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 807000),
#  u'data': [{...}, {...}],
#  u'importer': u'parteien',
#  u'name': u'Die Linke',
#  u'search': [u'die linke',
#              u'partei die linke',
#              u'linkspartei',
#              u'linksparteipds',
#              u'pds',
#              u'wasg',
#              u'partei des demokratischen sozialismus',
#              u'arbeit and soziale gerechtigkeit die wahlalternative',
#              u'wahlalternative',
#              u'wahlalternative arbeit und soziale gerechtigkeit'],
#  u'slug': u'die linke',
#  u'tags': [u'partei', u'linke'],
#  u'type': u'entity',
#  u'updated': datetime.datetime(2015, 5, 28, 18, 11, 12, 646000)}

# %% [markdown]
# Die direkten Felder des Dokuments sind (abgesehen von der Id):
#  _aliases, created, data, importer, name, search, slug, tags, type, updated_
#
#  Zur anschließenden Analyse wurde das Tool __Variety__ verwendet (https://github.com/variety/variety). Es hilft dabei, die Daten und ihr Struktur zu verstehen und einen Überblick über sie zu bekommen.

# %%
# We need to find the tool variety before we can use it
VARIETY = "../variety/variety.js"
if not exists(VARIETY):
     print("variety.js script NICHT in %s gefunden. Ausversehen verschoben?" % VARIETY)
        
# Save database analysis as JSON for processing 
shell_capture = ! mongo --quiet lobbyradar --eval "var collection = 'entities', outputFormat='json'" {VARIETY}
variety_schema_json = shell_capture.n

# And print as ascii
! mongo --quiet lobbyradar --eval "var collection = 'entities', outputFormat='ascii'" {VARIETY}
# Out:
# +------------------------------------------------------------------------------------------------+
# | key                      | types                        | occurrences | percents               |
# | ------------------------ | ---------------------------- | ----------- | ---------------------- |
# | _id                      | ObjectId                     |       26380 | 100.000000000000000000 |
# | aliases                  | Array                        |       26380 | 100.000000000000000000 |
# | created                  | Date                         |       26380 | 100.000000000000000000 |
# | data                     | Array                        |       26380 | 100.000000000000000000 |
# | importer                 | String,null                  |       26380 | 100.000000000000000000 |
# | name                     | String                       |       26380 | 100.000000000000000000 |
# | search                   | Array                        |       26380 | 100.000000000000000000 |
# | slug                     | String                       |       26380 | 100.000000000000000000 |
# | tags                     | Array                        |       26380 | 100.000000000000000000 |
# | type                     | String                       |       26380 | 100.000000000000000000 |
# | updated                  | Date                         |       26380 | 100.000000000000000000 |
# | data.XX.auto             | Boolean                      |       25742 |  97.581501137225174602 |
# | data.XX.created          | Date                         |       25742 |  97.581501137225174602 |
# | data.XX.desc             | String                       |       25742 |  97.581501137225174602 |
# | data.XX.format           | String                       |       25742 |  97.581501137225174602 |
# | data.XX.id               | String                       |       25742 |  97.581501137225174602 |
# | data.XX.key              | String                       |       25742 |  97.581501137225174602 |
# | data.XX.updated          | Date                         |       25742 |  97.581501137225174602 |
# | data.XX.value            | Boolean,Number,Object,String |       25742 |  97.581501137225174602 |
# | data.XX.value.url        | String                       |       25238 |  95.670962850644428954 |
# | data.XX.value.remark     | String                       |       25229 |  95.636846095526919953 |
# | data.XX.value.name       | String,null                  |        7950 |  30.136467020470053768 |
# | data.XX.value.addr       | String,null                  |        7946 |  30.121304018195601770 |
# | data.XX.value.city       | String,null                  |        7946 |  30.121304018195601770 |
# | data.XX.value.postcode   | String,null                  |        7946 |  30.121304018195601770 |
# | data.XX.value.type       | String                       |        7941 |  30.102350265352541214 |
# | data.XX.value.country    | String,null                  |        7606 |  28.832448824867324078 |
# | data.XX.value.street     | String,null                  |        5862 |  22.221379833206974297 |
# | data.XX.value.tel        | String,null                  |        2994 |  11.349507202426080354 |
# | data.XX.value.email      | String,null                  |        2921 |  11.072782410917362483 |
# | data.XX.value.fax        | String,null                  |        2610 |   9.893858984078848451 |
# | data.XX.value.www        | String                       |        2095 |   7.941622441243366026 |
# | data.XX.value.copyright  | String,null                  |         628 |   2.380591357088703397 |
# | data.XX.value.county     | String                       |         619 |   2.346474601971190399 |
# | data.XX.value.license    | String,null                  |         569 |   2.156937073540560856 |
# | data.XX.value.source_url | String                       |         549 |   2.081122062168309306 |
# | data.XX.value.date       | Date                         |           5 |   0.018953752843062926 |
# | data.XX.value.fmt        | String                       |           5 |   0.018953752843062926 |
# +------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Tags
#
# Da Tags ein Array ist, muss es in der Pipeline zunächst in seine Elemente aufgeteilt werden.

# %%
# Aggregation, die das "tags"-Array der Dokumente zerlegt und für jeden Wert einen neuen Eintrag im Resultset erzeugt.
# Diese werden anschließend gruppiert, die Gruppengrößen gezählt und entsprechend sortiert
pipeline = [
    {"$unwind": "$tags"},
    {"$group": {"_id": "$tags", "count": {"$sum": 1}}},
    {"$sort": {"count": -1} }
]

distinct_tags_count = list(db.entities.aggregate(pipeline, cursor={}))
pprint(distinct_tags_count)
#  {u'_id': u'ard', u'count': 1},
#  {u'_id': u'schule', u'count': 1},
#  {u'_id': u'getraenke', u'count': 1},
#  {u'_id': u'journal', u'count': 1},
#  {u'_id': u'alkohol', u'count': 1},
#  {u'_id': u'gsw', u'count': 1},
#  {u'_id': u'banken', u'count': 1},
#  {u'_id': u'arbeitgeber', u'count': 1},
#  {u'_id': u'provider', u'count': 1},
#  {u'_id': u'uhren', u'count': 1},
#  {u'_id': u'ratingagentur', u'count': 1},
#  {u'_id': u'eletronik', u'count': 1},
#  {u'_id': u'holz', u'count': 1},
#  {u'_id': u'landesr', u'count': 1},
#  {u'_id': u'unterhaltung', u'count': 1},
#  {u'_id': u'tabak', u'count': 1},
#  {u'_id': u'stockheim-media', u'count': 1},
#  {u'_id': u'public-affairs', u'count': 1},
#  {u'_id': u'pr', u'count': 1},
#  {u'_id': u'finanzdienstleistungen', u'count': 1},
#  {u'_id': u'tourismus', u'count': 1},
#  {u'_id': u'non-toxic-solar-alliance', u'count': 1},
#  {u'_id': u'handwerk', u'count': 1},
#  {u'_id': u'naher-osten', u'count': 1},
#  {u'_id': u'Umwelt', u'count': 1},
#  {u'_id': u'consultating', u'count': 1},
#  {u'_id': u'fern', u'count': 1},
#  {u'_id': u'terrorismus', u'count': 1},
#  {u'_id': u'moebel', u'count': 1},
#  {u'_id': u'bundeskanzlerin', u'count': 1},
#  {u'_id': u'srom', u'count': 1},
#  {u'_id': u'ngo', u'count': 1},
#  {u'_id': u'stakeholder-dialog', u'count': 1},
#  {u'_id': u'skandinavien', u'count': 1},
#  {u'_id': u'elektronik', u'count': 1},
#  {u'_id': u'laen', u'count': 1},
#  {u'_id': u'gruene', u'count': 1},
#  {u'_id': u'Medizin', u'count': 1},
#  {u'_id': u'recht', u'count': 1},
#  {u'_id': u'genussmittel', u'count': 1},
#  {u'_id': u'krisenkommunikation', u'count': 1},
#  {u'_id': u'bundesregierung', u'count': 1},
#  {u'_id': u'manager', u'count': 1},
#  {u'_id': u'medizin', u'count': 1},
#  {u'_id': u'steuern', u'count': 1},
#  {u'_id': u'literatur', u'count': 1},
#  {u'_id': u'polizei', u'count': 1},
#  {u'_id': u'ukraine', u'count': 1}]
# Total: 235 distinct tags.

# %% [markdown]
# ## Type

# %%
# Aggregation mit Gruppierung der Dokumente nach Feld "type", zählen der Gruppen und aufsteigend danach sortieren
pipeline = [ 
    { "$group": {"_id": "$type", "count": {"$sum": 1}} },
    { "$sort": {"count":1} }
]

distinct_types_count = list(db.entities.aggregate(pipeline, cursor={}))
pprint(distinct_types_count)
print("Total: %s distinct types." % len(distinct_types_count))
# Out:
# [{u'_id': u'entity', u'count': 6552}, {u'_id': u'person', u'count': 19828}]
# Total: 2 distinct types.

# %% [markdown]
# # Importer

# %%
# Aggregation mit Gruppierung der Dokumente nach Feld "importer", zählen der Gruppen und aufsteigend danach sortieren
pipeline = [ 
    { "$group": {"_id": "$importer", "count": {"$sum": 1}} },
    { "$sort": {"count": -1} }
]

distinct_importer_count = list(db.entities.aggregate(pipeline, cursor={}))
pprint(distinct_importer_count)
print("Total: %s distinct importer." % len(distinct_importer_count))
# Out:
# [{u'_id': u'lobbyliste', u'count': 16804},
#  {u'_id': u'parteispenden', u'count': 2914},
#  {u'_id': u'bundestag', u'count': 2046},
#  {u'_id': u'pr', u'count': 1767},
#  {u'_id': None, u'count': 1063},
#  {u'_id': u'dax', u'count': 541},
#  {u'_id': u'laender', u'count': 370},
#  {u'_id': u'parteispenden13', u'count': 311},
#  {u'_id': u'thinktanks', u'count': 309},
#  {u'_id': u'seitenwechsler', u'count': 214},
#  {u'_id': u'kabinette', u'count': 34},
#  {u'_id': u'parteispenden14', u'count': 6},
#  {u'_id': u'parteien', u'count': 1}]
# Total: 13 distinct importer.

# %%
pprint(list(entities.find({ "name": "Angela Merkel" })))
# Out:
# [{u'_id': ObjectId('54c2a4b4fe6a42c82bbaafac'),
#   u'aliases': [u'Dr. Angela Merkel', u'Angela Merkel'],
#   u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 772000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'9dc681ff88ef78470f58dad0a22fde397147a9f46b416478d2fd87233fa728ab',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'created by bundestag importer',
#                         u'url': u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/M/merkel_angela/258788'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Vornamen',
#              u'format': u'string',
#              u'id': u'dfdee4542498db7db194d7f76a2b7912d5de8efa322e97eb49c7bee72028fe7a',
#              u'key': u'names',
#              u'updated': datetime.datetime(2015, 3, 1, 20, 26, 4, 833000),
#              u'value': u'Merkel'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Nachname',
#              u'format': u'string',
#              u'id': u'269e458616080ba776b219361b1c466cd6157eb00094aea7839c2c36b8f05260',
#              u'key': u'surname',
#              u'updated': datetime.datetime(2015, 3, 1, 20, 26, 4, 833000),
#              u'value': u'Angela'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Foto',
#              u'format': u'photo',
#              u'id': u'0e7e0cd5aabfd09f92908d8e89c2c60290faad58b27beb26e15ba472814045c5',
#              u'key': u'photo',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'copyright': u'\xa9 CDU/ Dominik Butzmann ',
#                         u'url': u'https://www.bundestag.de/image/241388/Hochformat__2x3/177/265/8575bd619adc1928ffeaeef795d25c70/fD/merkel_angela_gross.jpg'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Foto',
#              u'format': u'photo',
#              u'id': u'3e300d356430fc5038727ff0af7059a74199c0861672b2d7ae687ad6e6c3d639',
#              u'key': u'photo',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'copyright': u'\xa9 Bundestagsfraktion CDU/CSU',
#                         u'url': u'http://www.abgeordnetenwatch.de/images/abgeordnete/big/78333/angela_merkel.jpg'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Foto',
#              u'format': u'photo',
#              u'id': u'7d475b70a04248869d31b70542b1f76a78bb9ffcc9be75085bc6f01130b2944b',
#              u'key': u'photo',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'copyright': u'Thaidigsmann',
#                         u'license': u'CC-BY-SA-4.0',
#                         u'source_url': u'http://de.wikipedia.org/wiki/Datei:Angela-Merkel-2014.jpg',
#                         u'url': u'https://upload.wikimedia.org/wikipedia/commons/4/43/Angela-Merkel-2014.jpg'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Foto',
#              u'format': u'photo',
#              u'id': u'0da4e7c210fda4b792f20d2f11400fff01a99c8c2d36d3468439de573e5408c6',
#              u'key': u'photo',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'copyright': u'Bildquelle:\xa0Armin Linnartz',
#                         u'license': u'http://creativecommons.org/licenses/by-sa/3.0/de/',
#                         u'url': u'https://www.cducsu.de/sites/default/files/AM_Juli_2010.jpg'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'7b1bf2b1dcc5f01795787247e66f922a0920330b00092f19fd2b164d0e17fd46',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'addr': None,
#                         u'email': u'angela.merkel@bundestag.de',
#                         u'name': u'Angela Merkel',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'bc81121f9662552f9cf6ec2a57ca1070b2659e61223f90cd57fee60b3c0d8d6a',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'addr': u'Berlin',
#                         u'city': u'Berlin',
#                         u'county': u'Germany',
#                         u'email': u'angela.merkel@bundestag.de',
#                         u'name': u'Angela Merkel',
#                         u'postcode': u'11011',
#                         u'street': u'Platz der Republik 1',
#                         u'tel': u'+493022778032',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'7cad8b18e268f9f73e07ab05dd2d0c8e1b36edf664e6d8c0e23a61fc0460a7e1',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'addr': u'Wahlkreis',
#                         u'city': u'Stralsund',
#                         u'county': u'Germany',
#                         u'email': u'angela.merkel@wk.bundestag.de',
#                         u'name': u'Angela Merkel',
#                         u'postcode': u'18439',
#                         u'street': u'Ossenreyer Str. 29',
#                         u'tel': u'+493831292783',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'4587b2e1aaa77a9bebcb9d652ddc7bcf666197f8d05214ca6cfd35893580838f',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Pers\xf6nliche Homepage',
#                         u'url': u'http://www.angela-merkel.de'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'0fdc0f4310a3e18359baa4c894304f3a03c2208a74d8ab80b2541ed29979065e',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Biografie auf Bundestag.de',
#                         u'url': u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/M/merkel_angela/258788'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'37282305c82b54d8557797aa903e025748670c24cfba71325480d46f19804a53',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Abgeordnetenwatch',
#                         u'url': u'http://www.abgeordnetenwatch.de/angela_merkel-778-78333.html'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'209c2c06b8f3a497f4ac8f13fb56f30261d5262ac4d28e884626c4d908eb7ed0',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Wikipedia',
#                         u'url': u'http://de.wikipedia.org/wiki/Angela_Merkel'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'03b6920f8f5bada1d94940dca5bd216c6d4c4dcfabc2344ed85f6763bb45a1f4',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Fraktion',
#                         u'url': u'https://www.cducsu.de/abgeordnete/angela-merkel'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Link',
#              u'format': u'link',
#              u'id': u'e1316e7c095776e94766631dc8db3086401172fcda6eab9c4f36da72e5d9cea4',
#              u'key': u'link',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': {u'remark': u'Facebook-Profil',
#                         u'url': u'https://www.facebook.com/AngelaMerkel'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Wahlkreis',
#              u'format': u'string',
#              u'id': u'11a87182ebe049cb82bf0b6df5174e3b1424f79182e4610294d156187ccf3d8a',
#              u'key': u'wahlkreis',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': u'15, '},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Bundesland',
#              u'format': u'string',
#              u'id': u'a6f31d89516a5409a535cedcc6fa7af753922e484fa96b14a8b486d76c44efe9',
#              u'key': u'bundesland',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': u'Mecklenburg-Vorpommern'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Benutzename BT-Cert',
#              u'format': u'string',
#              u'id': u'2cb53bbd10d231b46e02061c693c6db7165c369c2640b6d6993a251266078a7e',
#              u'key': u'btcertuid',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': u'merkelan_mdb'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'desc': u'Titel',
#              u'format': u'string',
#              u'id': u'08496e11d0a88958e9bd961999996f0453eb52f6dd8644641909aeb35e91e886',
#              u'key': u'titles',
#              u'updated': datetime.datetime(2015, 1, 30, 13, 16, 19, 123000),
#              u'value': u'Dr.'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 27, 5, 13, 53, 6000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'8d1d04db1bac50ae4bb6820e2db73fbfb7955172d020fd5461d872ce06af4205',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 27, 5, 13, 53, 6000),
#              u'value': {u'addr': None,
#                         u'email': u'angela.merkel@bundestag.de',
#                         u'name': u'Angela Merkel',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'desc': u'Quelle',
#              u'format': u'link',
#              u'id': u'235cf3d911fa8199c8b1cb6d0284e7db1620cd2baa35141aa546f5b705ef33c2',
#              u'key': u'source',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'value': {u'remark': u'created by parteispenden importer',
#                         u'url': u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'f00efa34d064b3d2526c25700f8f815874639e7d430b75ee05e2c178b1f08e5c',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'value': {u'addr': u'',
#                         u'city': u'Berlin',
#                         u'country': u'Germany',
#                         u'name': u'Angela Merkel',
#                         u'postcode': u'10785',
#                         u'street': u'Klingelh\xf6ferstra\xdfe 8',
#                         u'type': u'main'}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'desc': u'Vornamen',
#              u'format': u'string',
#              u'id': u'd7380ef7e2fd6f0e72ddd820c3cc9f7318aa868e2fbd671ab5b5c40e9458afbb',
#              u'key': u'names',
#              u'updated': datetime.datetime(2015, 3, 1, 20, 26, 4, 833000),
#              u'value': u'Angela'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 863000),
#              u'desc': u'Nachname',
#              u'format': u'string',
#              u'id': u'07025e1f91b25a220bbcf334d8b7a45327b545bcbf1f4c1e51c5f579d5510585',
#              u'key': u'surname',
#              u'updated': datetime.datetime(2015, 3, 1, 20, 26, 4, 833000),
#              u'value': u'Merkel'},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 44, 50, 772000),
#              u'desc': u'Adresse',
#              u'format': u'address',
#              u'id': u'5c5767eda8fb5734d36866f92eb9ea013687a1ae4e5748aa48789c956aa5d477',
#              u'key': u'address',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 44, 50, 772000),
#              u'value': {u'addr': u'',
#                         u'city': u'Bonn',
#                         u'country': u'Germany',
#                         u'name': u'Angela Merkel',
#                         u'postcode': u'53175',
#                         u'street': u'Kennedyallee 105-107',
#                         u'type': u'main'}}],
#   u'importer': u'parteispenden',
#   u'name': u'Angela Merkel',
#   u'search': [u'angela merkel', u'dr angela merkel'],
#   u'slug': u'angela merkel',
#   u'tags': [u'kabinette',
#             u'kabinett-merkel-i',
#             u'verwaltung',
#             u'politik',
#             u'kabinett-merkel-ii',
#             u'kabinett-merkel-iii',
#             u'mdb',
#             u'bundestag',
#             u'parteispenden',
#             u'bundeskanzlerin'],
#   u'type': u'person',
#   u'updated': datetime.datetime(2015, 4, 14, 15, 2, 44, 640000)}]

# %% [raw]
# # Entitäten mit Attribut "importer": "parteispenden14"
# query = {'type': 'entity', 'importer': 'parteispenden14'}
# projection = {'_id': 0, 'name': 1}
# for i in db.entities.find(query, projection):
#      pprint(i)
#
# print("%s Entitäten mit importer parteispenden14 gefunden" % db.entities.find(query, projection).count())

# %% [markdown]
# ## Data

# %% [raw]
# # Query on a array fields (here importer field)
# query = {'importer': "representative"}
# one_representative = db.entities.find_one(query)
# print("\"%s\" is a representative." % one_representative.get("name"))
# one_representative.get("tags")

# %% [markdown]
# # in compararion with
# print("Die Datenbank enthält %s Entitäten mit Tag Medien und %s Entitäten mit Tag lobbyismus" % (db.entities.find({'tags': "Medien"}).count(), db.entities.find({'tags': "lobbyismus"}).count()))

# %%
pprint(entities.find_one())
# Out:
# {u'_id': ObjectId('54bd3c748b934da06340f4c1'),
#  u'aliases': [u'DIE LINKE',
#               u'Die Linke',
#               u'Partei DIE LINKE',
#               u'DIE LINKE.',
#               u'Linkspartei',
#               u'Linkspartei.PDS',
#               u'PDS',
#               u'WASG',
#               u'Partei des Demokratischen Sozialismus',
#               u'Arbeit & soziale Gerechtigkeit \u2013 Die Wahlalternative',
#               u'Wahlalternative',
#               u'Wahlalternative Arbeit und soziale Gerechtigkeit'],
#  u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 807000),
#  u'data': [{u'auto': True,
#             u'created': datetime.datetime(2015, 5, 28, 18, 11, 9, 657000),
#             u'desc': u'Partei',
#             u'format': u'string',
#             u'id': u'2b1adb60a31d37cf9cc0fdccb75149456a425095c6bf5e77abac117ed1a69d0f',
#             u'key': u'partei',
#             u'updated': datetime.datetime(2015, 5, 28, 18, 11, 9, 657000),
#             u'value': u'Die Linke'},
#            {u'auto': True,
#             u'created': datetime.datetime(2015, 1, 19, 17, 18, 44, 808000),
#             u'desc': u'Adresse',
#             u'format': u'address',
#             u'id': u'bb4b34d6b3f916cea2ca09b7cea7842afbec6c9d303c3dc31a5823bda70658bb',
#             u'key': u'address',
#             u'updated': datetime.datetime(2015, 1, 19, 17, 18, 44, 808000),
#             u'value': {u'addr': u'Bundesgesch\xe4ftsstelle',
#                        u'city': u'Berlin',
#                        u'country': u'Deutschland',
#                        u'email': u'bundesgeschaeftsstelle@die-linke.de',
#                        u'fax': u'+493024009310',
#                        u'name': u'Partei DIE LINKE',
#                        u'postcode': u'10178',
#                        u'street': u'Kleine Alexanderstra\xdfe 28',
#                        u'tel': u'+493024009397',
#                        u'type': u'main',
#                        u'www': u'http://www.die-linke.de/'}}],
#  u'importer': u'parteien',
#  u'name': u'Die Linke',
#  u'search': [u'die linke',
#              u'partei die linke',
#              u'linkspartei',
#              u'linksparteipds',
#              u'pds',
#              u'wasg',
#              u'partei des demokratischen sozialismus',
#              u'arbeit and soziale gerechtigkeit die wahlalternative',
#              u'wahlalternative',
#              u'wahlalternative arbeit und soziale gerechtigkeit'],
#  u'slug': u'die linke',
#  u'tags': [u'partei', u'linke'],
#  u'type': u'entity',
#  u'updated': datetime.datetime(2015, 5, 28, 18, 11, 12, 646000)}
