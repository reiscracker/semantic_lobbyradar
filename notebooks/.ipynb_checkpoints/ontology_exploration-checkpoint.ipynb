# %%
import pymongo                                                                                                                                                                                                                               
from pymongo import MongoClient                                                                                                                                                                                                              
from pprint import pprint#, pformat, PrettyPrinter                                                                                                                                                                                            
# from bson.son import SON                                                                                                                                                                                                                     
from bson.objectid import ObjectId                                                                                                                                                                                                           
# from os.path import exists                                                                                                                                                                                                                   
# import json                                                                                                                                                                                                                                  
# from ipy_table import *        

from helpers import *

# %%
def formatRow(row):
    formats = { 2: u"{}: {}", 3: u"{}: {} ({})" }
    row_format = formats.get( len(row), u"{} " * len(row) )
    return (row_format.format(*row.values()))

# %%
# Connect to database and create variables for the collections                                                                                                                                                                                 
client = MongoClient()                                                                                                                                                                                                                       
db = client.lobbyradar                                                                                                                                                                                                                       
entities, relations = db.entities, db.relations

print("%s Entities and %s Relations loaded." % (entities.count(), relations.count()))
# Out:
# 26380 Entities and 32137 Relations loaded.

# %%
etools = helpers.MongoHelper(entities)
rtools = helpers.MongoHelper(relations)

# %% [markdown]
# # Ontologie
# Um eine Ontologie zu bauen müssen wir uns auf Klasse und Eigenschaften festlegen. Es geht nun also darum, die Daten gut zu untersuchen und die wichtigsten Klassen daraus abzuleiten.
#
# Grundlegend geht es in diesem Datensatz um Vernetzung, weshalb die "Verbindung" so gut wie allen Relationen zu Grunde liegt.

# %% [markdown]
# Auf Seiten der Relationen sind die Felder
#  - Tags
#  - data.desc
#  - data.format
#  - data.value.position
#  - data.value.type
#  - data.value.desc
#  - data.value.amount
#  - data.value.activity
#
# besonders aussagekräftig und bieten viele Daten.

# %% [markdown]
# ### Tags
# Die Tags bieten relativ viel Informationen, dafür leider unstrukturiert. Da es viele wenig genutzte Tags gibt, schränken wir die Suche etwas ein.

# %%
# Filter Tags with less than 100 occurences
pipeline = make_pipeline(unwind="tags", group="tags", sort=True, min_count=100)

tags = relations.aggregate(pipeline , cursor={})
printCols( [ formatRow(row) for row in tags ], spacing=20)
# Out:
# 3926: partei        2552: nebentaetigkeit1804: committee     1151: pr-und-lobbyagentur1081: spende
# 1081: parteispende  1047: anwaltskanzlei675: dax            629: mdb            603: laender
# 557: kabinette      496: aufsichtsrat   466: pharma         281: seitenwechsler 245: bank
# 230: regierung      229: kabinett       220: ruestung       192: vorstand       174: fernsehrat
# 168: fernsehen      154: auto

# %% [markdown]
# ### data.XX.desc  | data.XX.format

# %%
desc_pipeline = make_pipeline(unwind="data", group="data.desc", sort=True, min_count=100)
format_pipeline = make_pipeline(unwind="data", group="data.format", sort=True, min_count=100)
desc = relations.aggregate(desc_pipeline, cursor={})
form = relations.aggregate(format_pipeline, cursor={})

printCols( [ u"{:<60} {:<50}".format(d, f) for (d, f) in zip(desc, form) ], columns=1 )
# Out:
# {u'count': 26258, u'_id': u'Verbindung'}                     {u'count': 26258, u'_id': u'association'}
# {u'count': 9673, u'_id': u'Parteispende'}                    {u'count': 9673, u'_id': u'donation'}
# {u'count': 2673, u'_id': u'Angaben zur Nebent\xe4tigkeit'}   {u'count': 2673, u'_id': u'activity'}

# %% [markdown]
# Hier sehen wir deutlich, dass data.desc und data.format so gut wie deckungsgleich sehen. Es reicht also, wenn wir eines der Felder betrachten.
# Auch data.key ist fast gleichbedeutend damit.

# %% [markdown]
# ### data.value.position

# %%
position_pipeline = make_pipeline(unwind="data", group="data.value.position", sort=True, min_count=100)
position = relations.aggregate(position_pipeline, cursor={})

printCols( [ formatRow(row) for row in position ], columns=4, spacing=40)
# Out:
# 16054: Vorstand                         11394: None                             2635: Mitglied                          993: Ordentliches Mitglied
# 838: Stellvertretendes Mitglied         837: Arbeitsverhältnis                  459: Aufsichtsratsmitglied              404: Mitglied des Kuratoriums
# 231: Mitglied des Beirates              204: Mitglied des Aufsichtsrates        173: Mitglied des Vorstandes            161: Vorstandsmitglied
# 122: Staatssekretär                     115: Mitglied im Rundfunkrat            111: Mitglied des Kreistages

# %% [markdown]
# Natürlicherweise sind alle Vorstände auch immer assoziiert mit dem jeweiligen Partner:

# %%
p = [
 {'$unwind': '$data'},
 {'$match': {'data.format': {'$eq': "association"}}},
 {'$group': {'_id': { 'position': '$data.value.position', 'format': '$data.format'}, 'count': {'$sum': 1}}},
 {'$sort': {'count': -1}},
 {'$match': {'count': {'$gt': 100}}} 
]
printCols( [ formatRow(row) for row in relations.aggregate(p) ], columns=2, spacing=90)
# Out:
# 16054: {u'position': u'Vorstand', u'format': u'association'}                              2635: {u'position': u'Mitglied', u'format': u'association'}
# 1490: {u'format': u'association'}                                                         993: {u'position': u'Ordentliches Mitglied', u'format': u'association'}
# 838: {u'position': u'Stellvertretendes Mitglied', u'format': u'association'}              837: {u'position': u'Arbeitsverh\xe4ltnis', u'format': u'association'}
# 459: {u'position': u'Aufsichtsratsmitglied', u'format': u'association'}                   161: {u'position': u'Vorstandsmitglied', u'format': u'association'}
# 122: {u'position': u'Staatssekret\xe4r', u'format': u'association'}                       115: {u'position': u'Mitglied im Rundfunkrat', u'format': u'association'}

# %% [markdown]
# Dass eine Spende zusammen mit einer "Position" eintritt ist eher seltener..

# %%
p = [
 {'$unwind': '$data'},
 {'$match': {'data.format': {'$eq': "donation"}}},
 {'$group': {'_id': { 'position': '$data.value.position', 'format': '$data.format'}, 'count': {'$sum': 1}}},
 {'$sort': {'count': -1}},
 {'$match': {'count': {'$gt': 100}}} 
]
printCols( [ formatRow(row) for row in relations.aggregate(p) ], columns=2, spacing=90)
# Out:
# 9673: {u'format': u'donation'}

# %% [markdown]
# Bei der activity gibt es wieder Personen, die eine Position innehaben.

# %%
p = [
 {'$unwind': '$data'},
 {'$match': {'data.format': {'$eq': "activity"}}},
 {'$group': {'_id': { 'position': '$data.value.position', 'format': '$data.format'}, 'count': {'$sum': 1}}},
 {'$sort': {'count': -1}},
 {'$match': {'count': {'$gt': 100}}} 
]
printCols( [ formatRow(row) for row in relations.aggregate(p) ], columns=2, spacing=90)
# Out:
# 324: {u'position': u'Mitglied des Kuratoriums', u'format': u'activity'}                   229: {u'position': u'Mitglied des Beirates', u'format': u'activity'}
# 228: {u'position': None, u'format': u'activity'}                                          203: {u'position': u'Mitglied des Aufsichtsrates', u'format': u'activity'}
# 169: {u'position': u'Mitglied des Vorstandes', u'format': u'activity'}                    110: {u'position': u'Mitglied des Kreistages', u'format': u'activity'}

# %% [markdown]
# ### data.value.type

# %%
type_pipeline = make_pipeline(unwind="data", group="data.value.type", sort=True, min_count=50)
types = relations.aggregate(type_pipeline, cursor={})

printCols( [ formatRow(row) for row in types ], columns=2)
# Out:
# 17212: executive              12338: None
# 5129: member                  1598: job
# 1445: business                633: government
# 82: subsidiary                64:

# %%
subsidiary = relations.find({ "data.value.type": {"$eq": "subsidiary"} }, {'tags': 1, 'data.value': 1, 'entities': 1}).limit(3)
for r in subsidiary:
    pprint(r)
# Out:
# {u'_id': ObjectId('54ca5b4266c1658e2ecfbdb9'),
#  u'data': [{u'value': {u'position': u'', u'type': u'subsidiary'}}],
#  u'entities': [ObjectId('54c2a4cafe6a42c82bbab93d'),
#                ObjectId('54bd3ca38b934da0634177da')],
#  u'tags': [u'ruestung']}
# {u'_id': ObjectId('54db26ae45666daa087dd7a7'),
#  u'data': [{u'value': {u'position': u'', u'type': u'subsidiary'}}],
#  u'entities': [ObjectId('54c2a4b3fe6a42c82bbaaf7e'),
#                ObjectId('54bd3ca18b934da063417539')],
#  u'tags': []}
# {u'_id': ObjectId('54db280545666daa087dd7a9'),
#  u'data': [{u'value': {u'position': u'', u'type': u'subsidiary'}}],
#  u'entities': [ObjectId('54c2a4b3fe6a42c82bbaaf7e'),
#                ObjectId('54cb842abbde97945a06a06f')],
#  u'tags': []}

# %%
def lookup_relation(relation_id):
    relation = relations.find_one({ "_id": relation_id }, {'tags': 1, 'data': 1, 'entities': 1})  
    entity_ids = relation.get('entities')
    pprint(relation.get('data'))
    print(etools.lookup_entity(entitiy_ids[0], {'name': 1}))
    print(etools.lookup_entity(entitiy_ids[1], {'name': 1}))
    
def lookup_by_value_desc(value_desc):
    relation = relations.find_one({ "data.value.desc": value_desc }, {'tags': 1, 'data': 1, 'entities': 1})  
    entity_ids = relation.get('entities')
    pprint(relation.get('data'))
    print(etools.lookup_entity(entitiy_ids[0], {'name': 1}))
    print(etools.lookup_entity(entitiy_ids[1], {'name': 1}))

# %%
entitiy_ids = (ObjectId('54c2a4cafe6a42c82bbab93d'), ObjectId('54bd3ca38b934da0634177da'))
print(etools.lookup_entity(entitiy_ids[0], {'name': 1}))
print(etools.lookup_entity(entitiy_ids[1], {'name': 1}))
# Out:
# {u'_id': ObjectId('54c2a4cafe6a42c82bbab93d'), u'name': u'Jena Optronic GmbH'}
# {u'_id': ObjectId('54bd3ca38b934da0634177da'), u'name': u'Airbus Group'}

# %%
entitiy_ids = (ObjectId('54c2a4b3fe6a42c82bbaaf7e'),
               ObjectId('54bd3ca18b934da063417539'))
print(etools.lookup_entity(entitiy_ids[0], {'name': 1}))
print(etools.lookup_entity(entitiy_ids[1], {'name': 1}))
# Out:
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54bd3ca18b934da063417539'), u'name': u'Bertelsmann-Stiftung'}

# %%
entitiy_ids = (ObjectId('54c2a4b3fe6a42c82bbaaf7e'),
               ObjectId('54cb842abbde97945a06a06f'))
print(etools.lookup_entity(entitiy_ids[0], {'name': 1}))
print(etools.lookup_entity(entitiy_ids[1], {'name': 1}))
# Out:
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}

# %% [markdown]
# ### data.value.desc

# %%
desc_pipeline = make_pipeline(unwind="data", group="data.value.desc", sort=True, min_count=50)
descs = relations.aggregate(desc_pipeline, cursor={})

printCols( [ formatRow(row) for row in descs ], columns=2, spacing=70)
# Out:
# 34325: None                                                           1435: Geschäftsverbindung
# 1220: Funktionen in Vereinen, Verbänden und Stiftungen                682: Funktionen in Körperschaften und Anstalten des öffentlichen Rechts
# 468: Funktionen in Unternehmen                                        298: Entgeltliche Tätigkeiten neben dem Mandat
# 58: Bundestag Spenden von Personen und Beiträge von Mandatsträgern

# %%
lookup_by_value_desc("Funktionen in Unternehmen")
# Out:
# [{u'auto': True,
#   u'created': datetime.datetime(2015, 1, 30, 13, 16, 52, 128000),
#   u'desc': u'Angaben zur Nebent\xe4tigkeit',
#   u'format': u'activity',
#   u'id': u'97748cdc9e054fcd94a1f98f398cfc84ee2a2762291348635b4a79384bf5339a',
#   u'key': u'activity',
#   u'updated': datetime.datetime(2015, 1, 30, 13, 16, 52, 128000),
#   u'value': {u'activity': None,
#              u'desc': u'Funktionen in Unternehmen',
#              u'end': None,
#              u'level': 0,
#              u'periodical': u'einmalig',
#              u'place': None,
#              u'position': u'Mitglied des Aufsichtsrates',
#              u'start': None,
#              u'unsalaried': True}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}

# %%
lookup_by_value_desc("Geschäftsverbindung")
# Out:
# [{u'desc': u'Verbindung',
#   u'format': u'association',
#   u'importer': u'created by pr importer',
#   u'key': u'association',
#   u'value': {u'desc': u'Gesch\xe4ftsverbindung',
#              u'sources': [u'http://www.bohnen-kallmorgen.com/'],
#              u'type': u'business'}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}

# %%
lookup_by_value_desc("Funktionen in Vereinen, Verbänden und Stiftungen")
# Out:
# [{u'auto': True,
#   u'created': datetime.datetime(2015, 1, 30, 13, 16, 53, 6000),
#   u'desc': u'Angaben zur Nebent\xe4tigkeit',
#   u'format': u'activity',
#   u'id': u'bd5fff82726759130d968abda0494dd38ff13e2d66e432b18c6c8dab0961043f',
#   u'key': u'activity',
#   u'updated': datetime.datetime(2015, 1, 30, 13, 16, 53, 6000),
#   u'value': {u'activity': None,
#              u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#              u'end': None,
#              u'level': 0,
#              u'periodical': u'einmalig',
#              u'place': None,
#              u'position': u'Vorsitzende',
#              u'start': None,
#              u'unsalaried': True}},
#  {u'desc': u'Verbindung',
#   u'format': u'association',
#   u'importer': u'created by lobbyliste importer',
#   u'key': u'association',
#   u'value': {u'position': u'Vorstand',
#              u'sources': [u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'],
#              u'type': u'executive'}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}

# %%
lookup_by_value_desc("Funktionen in Körperschaften und Anstalten des öffentlichen Rechts")
# Out:
# [{u'auto': True,
#   u'created': datetime.datetime(2015, 1, 30, 13, 16, 51, 597000),
#   u'desc': u'Angaben zur Nebent\xe4tigkeit',
#   u'format': u'activity',
#   u'id': u'd94f252e5e8a91dab2063c1db592f3c49f6f8db5ab68bf3617d415cb0eb87f23',
#   u'key': u'activity',
#   u'updated': datetime.datetime(2015, 1, 30, 13, 16, 51, 597000),
#   u'value': {u'activity': None,
#              u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#              u'end': None,
#              u'level': 0,
#              u'periodical': u'einmalig',
#              u'place': None,
#              u'position': u'Mitglied des Stadtrates',
#              u'start': None,
#              u'unsalaried': False}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}

# %% [markdown]
# ### data.value.amount

# %%
amount_pipeline = make_pipeline(unwind="data", group="data.value.amount", sort=True, min_count=50)
amounts = relations.aggregate(amount_pipeline, cursor={})

printCols( [ formatRow(row) for row in amounts ], columns=2)
# Out:
# 28934: None                   272: 15000
# 263: 20000                    145: 25000
# 124: 50000                    117: 12000
# 116: 12782.25                 98: 15338.7
# 94: 30000                     81: 11000
# 65: 12500                     64: 10500
# 62: 25564.5                   57: 13000

# %%
amounts = relations.find({ "data.value.amount": {"$exists": 1}}).limit(2)
pprint(list(amounts))
# Out:
# [{u'_id': ObjectId('54c2a4f0fe6a42c82bbabb54'),
#   u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 563000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 532000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'8744c78b0d974e477285b33b874cbaddd1962043cea900f5c4f3094ebb590ccb',
#              u'importer': u'created by parteispenden importer',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 45, 52, 532000),
#              u'value': {u'amount': 16872.57,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 1994}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 47, 9, 848000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'8c5fe66733aba6f4143094f464a0ca759580be5b0775f3b9545ae648ffe3824f',
#              u'importer': u'created by parteispenden importer',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 47, 9, 848000),
#              u'value': {u'amount': 12500,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2004}}],
#   u'entities': [ObjectId('54c2a4b3fe6a42c82bbaaf73'),
#                 ObjectId('552ff9cdaf9ee96e1c1df7bf')],
#   u'importer': u'parteispenden',
#   u'tags': [u'partei'],
#   u'type': u'general',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 47, 9, 863000),
#   u'weight': 1},
#  {u'_id': ObjectId('54c2a4f0fe6a42c82bbabb55'),
#   u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 673000),
#   u'data': [{u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 647000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'bafefe61854ea83d496d5d12d7c2f8d27f2b7f8290a8590b3373a28bf84e015b',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 45, 52, 647000),
#              u'value': {u'amount': 15338.7,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 1994}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 47, 1, 194000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'5980ff7509aae08ab740314bcb36708d981226759d75b702458011a381d7b0c7',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 47, 1, 194000),
#              u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2003}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 47, 51, 759000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'f3994468da7f5b9c8e0edbf480f446e8cbb85418cd99a5175b207071ddd5e3d0',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 47, 51, 759000),
#              u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2007}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 48, 4, 878000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'3ed635030d3af1531f3a62c79de1be9d20bcc0e1aa4b11aa67e2035fbbf7713d',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 48, 4, 879000),
#              u'value': {u'amount': 16000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2008}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 48, 45, 963000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'497696a96f682666888c2667433f4be8d136064f5c14af68279df45fccfe7ced',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 48, 45, 963000),
#              u'value': {u'amount': 16000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2010}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 1, 23, 19, 49, 2, 812000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'0f0898efe88b8e96ad746ef7e8fdfbc736080f9166ec20e222cf908313c909ca',
#              u'importer': u'Parteispenden',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 1, 23, 19, 49, 2, 812000),
#              u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2011}},
#             {u'auto': True,
#              u'created': datetime.datetime(2015, 5, 28, 18, 11, 17, 168000),
#              u'desc': u'Parteispende',
#              u'format': u'donation',
#              u'id': u'590dd4cee365f72ba4ae6f97d3b4d977674f9fa2cdb4b799d97de202236f1bd0',
#              u'importer': u'Bundestag Spenden von Personen und Beitr\xe4ge von Mandatstr\xe4gern',
#              u'key': u'donation',
#              u'updated': datetime.datetime(2015, 5, 28, 18, 11, 17, 168000),
#              u'value': {u'amount': 22500,
#                         u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#                         u'year': 2013}}],
#   u'entities': [ObjectId('54c2a4b3fe6a42c82bbaaf74'),
#                 ObjectId('552ff9cdaf9ee96e1c1df7bf')],
#   u'importer': u'parteispenden',
#   u'tags': [u'partei', u'spende', u'parteispende'],
#   u'type': u'general',
#   u'updated': datetime.datetime(2015, 5, 28, 18, 11, 17, 171000),
#   u'weight': 1}]

# %% [markdown]
# ### Beide relation-IDs stammen von einer Parteispende-Beziehung

# %%
pprint(lookup_relation(ObjectId('54c2a4f0fe6a42c82bbabb54')))
pprint(lookup_relation(ObjectId('54c2a4f0fe6a42c82bbabb55')))
# Out:
# [{u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 532000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'8744c78b0d974e477285b33b874cbaddd1962043cea900f5c4f3094ebb590ccb',
#   u'importer': u'created by parteispenden importer',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 45, 52, 532000),
#   u'value': {u'amount': 16872.57,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 1994}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 47, 9, 848000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'8c5fe66733aba6f4143094f464a0ca759580be5b0775f3b9545ae648ffe3824f',
#   u'importer': u'created by parteispenden importer',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 47, 9, 848000),
#   u'value': {u'amount': 12500,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2004}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}
# None
# [{u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 45, 52, 647000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'bafefe61854ea83d496d5d12d7c2f8d27f2b7f8290a8590b3373a28bf84e015b',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 45, 52, 647000),
#   u'value': {u'amount': 15338.7,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 1994}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 47, 1, 194000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'5980ff7509aae08ab740314bcb36708d981226759d75b702458011a381d7b0c7',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 47, 1, 194000),
#   u'value': {u'amount': 15000,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2003}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 47, 51, 759000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'f3994468da7f5b9c8e0edbf480f446e8cbb85418cd99a5175b207071ddd5e3d0',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 47, 51, 759000),
#   u'value': {u'amount': 15000,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2007}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 48, 4, 878000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'3ed635030d3af1531f3a62c79de1be9d20bcc0e1aa4b11aa67e2035fbbf7713d',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 48, 4, 879000),
#   u'value': {u'amount': 16000,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2008}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 48, 45, 963000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'497696a96f682666888c2667433f4be8d136064f5c14af68279df45fccfe7ced',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 48, 45, 963000),
#   u'value': {u'amount': 16000,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2010}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 1, 23, 19, 49, 2, 812000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'0f0898efe88b8e96ad746ef7e8fdfbc736080f9166ec20e222cf908313c909ca',
#   u'importer': u'Parteispenden',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 1, 23, 19, 49, 2, 812000),
#   u'value': {u'amount': 15000,
#              u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#              u'year': 2011}},
#  {u'auto': True,
#   u'created': datetime.datetime(2015, 5, 28, 18, 11, 17, 168000),
#   u'desc': u'Parteispende',
#   u'format': u'donation',
#   u'id': u'590dd4cee365f72ba4ae6f97d3b4d977674f9fa2cdb4b799d97de202236f1bd0',
#   u'importer': u'Bundestag Spenden von Personen und Beitr\xe4ge von Mandatstr\xe4gern',
#   u'key': u'donation',
#   u'updated': datetime.datetime(2015, 5, 28, 18, 11, 17, 168000),
#   u'value': {u'amount': 22500,
#              u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#              u'year': 2013}}]
# {u'_id': ObjectId('54c2a4b3fe6a42c82bbaaf7e'), u'name': u'Bertelsmann SE & Co. KGaA'}
# {u'_id': ObjectId('54cb842abbde97945a06a06f'), u'name': u'RTL Television GmbH'}
# None

# %%
amounts = relations.find({ "data.value.amount": {"$exists": 1}}, {'data.value': 1}).limit(2)
pprint(list(amounts))
# Out:
# [{u'_id': ObjectId('54c2a4f0fe6a42c82bbabb54'),
#   u'data': [{u'value': {u'amount': 16872.57,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 1994}},
#             {u'value': {u'amount': 12500,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2004}}]},
#  {u'_id': ObjectId('54c2a4f0fe6a42c82bbabb55'),
#   u'data': [{u'value': {u'amount': 15338.7,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 1994}},
#             {u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2003}},
#             {u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2007}},
#             {u'value': {u'amount': 16000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2008}},
#             {u'value': {u'amount': 16000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2010}},
#             {u'value': {u'amount': 15000,
#                         u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#                         u'year': 2011}},
#             {u'value': {u'amount': 22500,
#                         u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#                         u'year': 2013}}]}]

# %% [markdown]
# ### data.value.activity

# %%
activity_pipeline = make_pipeline(unwind="data", group="data.value.activity", sort=True)
activities = relations.aggregate(activity_pipeline, cursor={})

printCols( [ formatRow(row) for row in activities ], columns=3, spacing=70)
# Out:
# 38418: None                                                           62: Rechtsanwalt                                                      33: Vortrag
# 8: Betriebsleiter                                                     7: Beratung                                                           4: Rechtsanwältin
# 3: Rechtsanwalt und Notar                                             3: Wissenschaftliche Beratung                                         3: Publizistische Tätigkeit
# 2: Autorin                                                            2: Betreuerin                                                         2: Landwirt/Geschäftsführer
# 2: Wirtschaftsprüfer/Steuerberater                                    2: Landwirt                                                           2: Berater, freiberuflich
# 1: Lehrbeauftragte                                                    1: Kunde 10                                                           1: Kunde 09
# 1: Kunde 02                                                           1: Streitgespräch                                                     1: Studienreferendar
# 1: Vortrag: Kundenseminar                                             1: Vortrag und Podiumsdiskussion auf dem 3. Kongress der HUK-Coburg-Rechtsschutzversicherung1: Vortrag: Transplantationssymposium
# 1: Unternehmensberater                                                1: Podiumsdiskussion                                                  1: Vortrags-Lehr- und Prüfungstätigkeit
# 1: Rede und Podiumsdiskussion                                         1: Konferenzmitwirkung                                                1: Metzgermeister
# 1: Kunde 04                                                           1: Glasermeister                                                      1: Kunde 03
# 1: ARD Medienpreis                                                    1: Seminarleiterin                                                    1: politisches Podiumsgespräch
# 1: Autorenhonorar                                                     1: Universitätsprofessor                                              1: Publikation
# 1: Kunde 08                                                           1: Vortrag bei der Veranstaltungsreihe „Die Zukunft der Demokratie"   1: Moderation
# 1: Diskussionsrunde                                                   1: Vortragsreihe                                                      1: Podiumsdiskussion: "Das Freihandelsabkommen TTIP - Chance oder Schreckensvision für Europa"
# 1: Architektin                                                        1: Kaufmann                                                           1: Honorarprofessorin
# 1: Privatdozent                                                       1: Lesung                                                             1: Unternehmer
# 1: Historiker                                                         1: Mitwirkung in der TV-Sendung "Zimmer frei!"                        1: Vortrag: GKV-Infotag
# 1: Leiter des Reit-Zucht- und Ausbildungsstalles Markwerben           1: Seminardurchführung, Training                                      1: Geschäftsführer
# 1: Kunde 01                                                           1: Richterin                                                          1: Herausgeber
# 1: Dozent und Prüfer                                                  1: Bankkauffrau                                                       1: Leitender Angestellter
# 1: Zusatzhonorar 2013                                                 1: Arzt                                                               1: Vortrag: Qualitätskongress
# 1: Vermittlung von Versicherungsleistungen                            1: Moderation: Arzneimittelversorgung                                 1: Buchautor

# %%
list(relations.aggregate(make_pipeline(unwind='data', group='data.value', sort=True)))
# Out:
# [{u'_id': {u'position': u'Vorstand',
#    u'sources': [u'http://bundestag.de/blob/189476/8989cc5f5f65426215d7e0233704b20a/lobbylisteaktuell-data.pdf'],
#    u'type': u'executive'},
#   u'count': 15809},
#  {u'_id': {u'position': u'Mitglied', u'type': u'member'}, u'count': 364},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 159},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.freshfields.com/newsandinsights.aspx?language=de&region=germany&itemtype=News&LangId=1031&SearchRegion=Global&cbDeals=true'],
#    u'type': u'business'},
#   u'count': 141},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Aufsichtsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 124},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.hengeler.com'],
#    u'type': u'business'},
#   u'count': 124},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.freshfields.com/newsandinsights.aspx?language=de&region=germany&itemtype=News&LangId=1031&SearchRegion=Global&cbDeals=true'],
#    u'type': u'job'},
#   u'count': 120},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.hkstrategies.com/expertise/case-studies'],
#    u'type': u'business'},
#   u'count': 118},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.cliffordchance.com'],
#    u'type': u'business'},
#   u'count': 111},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://ec.europa.eu/transparencyregister/public/consultation/displaylobbyist.do?id=56047191389-84'],
#    u'type': u'business'},
#   u'count': 100},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Vorstandes',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 97},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.hengeler.com'],
#    u'type': u'job'},
#   u'count': 88},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Beirates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 87},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.bakermckenzie.com/'],
#    u'type': u'job'},
#   u'count': 85},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.cliffordchance.com'],
#    u'type': u'job'},
#   u'count': 85},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://lobbypedia.de/wiki/Seitenwechsler_in_Deutschland_im_%C3%9Cberblick'],
#    u'type': u'member'},
#   u'count': 85},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kreistages',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 84},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 80},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://linklaters.de/aktuelles/presse/pressemitteilungen.html'],
#    u'type': u'business'},
#   u'count': 69},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://linklaters.de/aktuelles/presse/pressemitteilungen.html'],
#    u'type': u'job'},
#   u'count': 69},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.bakermckenzie.com/'],
#    u'type': u'business'},
#   u'count': 58},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://www.atlantik-bruecke.org/service/dokumente/a-message-from-germany.pdf'],
#    u'type': u'member'},
#   u'count': 56},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.ogilvy.com/'],
#    u'type': u'business'},
#   u'count': 56},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://ec.europa.eu/transparencyregister/public/consultation/displaylobbyist.do?id=7223777790-86'],
#    u'type': u'business'},
#   u'count': 55},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/Burson-Marsteller'],
#    u'type': u'business'},
#   u'count': 55},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/WilmerHale'],
#    u'type': u'business'},
#   u'count': 53},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.strukturgesellschaft.de/?loc=menue4'],
#    u'type': u'member'},
#   u'count': 52},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Vorstandes',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 51},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Beirates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 49},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'https://lobbypedia.de/wiki/WilmerHale'],
#    u'type': u'job'},
#   u'count': 47},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.fischerappelt.de'],
#    u'type': u'business'},
#   u'count': 45},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'https://lobbypedia.de/wiki/Hering_Schuppener'],
#    u'type': u'job'},
#   u'count': 42},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung', u'type': u'business'},
#   u'count': 42},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Vorsitzender',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 41},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 40},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Verwaltungsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 40},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Stadtrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 37},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied im Rundfunkrat',
#    u'sources': [u'http://www.swr.de/unternehmen/gremien/gremien/-/id=12338976/did=13695516/nid=12338976/1do440o/index.html'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 36},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Kuratoriums',
#    u'sources': [u'http://www.kriminalpraevention.de/kuratorium.html'],
#    u'start': {},
#    u'type': u'job',
#    u'verified': True},
#   u'count': 34},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.beckerbuettnerheld.de'],
#    u'type': u'job'},
#   u'count': 32},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.akdae.de/Kommission/Organisation/Mitglieder/OM/index.html'],
#    u'type': u'member'},
#   u'count': 31},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 31},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 31},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 31},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Beirates',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 30},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 30},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2011},
#   u'count': 30},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied im Rundfunkrat',
#    u'sources': [u'http://www.rbb-online.de/rundfunkrat/mitglieder/rbb-rundfunkrat-mitglieder.html'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 29},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Stiftungsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 29},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.s-f.com/'],
#    u'type': u'business'},
#   u'count': 29},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 29},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Parlamentarischen Beirates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 29},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.db-law.de'],
#    u'type': u'job'},
#   u'count': 28},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2012},
#   u'count': 28},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/Edelman'],
#    u'type': u'business'},
#   u'count': 27},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 27},
#  {u'_id': {u'position': u'Assoziiert', u'type': u''}, u'count': 26},
#  {u'_id': {u'end': {},
#    u'sources': [],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 26},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 26},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 25},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied im Rundfunkrat',
#    u'sources': [u'https://www.br.de/unternehmen/inhalt/rundfunkrat/mitglieder100.html'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 24},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.bohnen-kallmorgen.com/'],
#    u'type': u'business'},
#   u'count': 24},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 24},
#  {u'_id': {u'type': u'committee'}, u'count': 23},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Vorsitzender',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 23},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Vorsitzende',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 23},
#  {u'_id': {u'position': u'Pr\xe4sidialmitglied',
#    u'sources': [u'http://www.bdi.eu/Praesidium.htm'],
#    u'type': u'executive'},
#   u'count': 23},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2007},
#   u'count': 23},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 23},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.aspectconsulting.eu'],
#    u'type': u'business'},
#   u'count': 22},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 22},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1994},
#   u'count': 22},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://de.wikipedia.org/wiki/Enquete-Kommission_Internet_und_digitale_Gesellschaft'],
#    u'type': u'member',
#    u'verified': True},
#   u'count': 21},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/Hering_Schuppener'],
#    u'type': u'business'},
#   u'count': 21},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Beirates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 21},
#  {u'_id': {u'position': u'', u'type': u'subsidiary'}, u'count': 21},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.orca-affairs.de'],
#    u'type': u'business'},
#   u'count': 21},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Pr\xe4sidiums',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 21},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.koch-consulting.de'],
#    u'type': u'business'},
#   u'count': 20},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2011},
#   u'count': 20},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1994},
#   u'count': 20},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.rwe.com/web/cms/de/8356/rwe/ueber-rwe/aufsichtsrat/'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.dpdhl.com/de/investoren/corporate_governance/aufsichtsrat.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.daimler.com/dccom/0-5-65181-49-79600-1-0-0-0-0-0-0-7145-0-0-0-0-0-0-0.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.thyssenkrupp.com/de/konzern/aufsichtsrat.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Stiftungsrates',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.commerzbank.de/media/de/konzern_1/konzerninfo/aufsicht/aufsichtsrat_der_commerzbank_ag.pdf'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://investor-relations.lufthansagroup.com/corporate-governance/aufsichtsrat.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.siemens.com/about/de/management_unternehmensstruktur/aufsichtsrat.htm'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2007},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.bmwgroup.com/bmwgroup_prod/d/0_0_www_bmwgroup_com/unternehmen/unternehmensprofil/aufsichtsrat/aufsichtsrat.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1998},
#   u'count': 19},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.continental-corporation.com/www/portal_com_de/themen/continental/vors/aufsichtsrat_zusammensetzung_de.html'],
#    u'type': u'executive'},
#   u'count': 19},
#  {u'_id': {u'end': {},
#    u'sources': [],
#    u'start': {},
#    u'type': u'subsidiary',
#    u'verified': True},
#   u'count': 18},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.munichre.com/de/ir/shareholder-information/corporate-governance/supervisory-board/index.html'],
#    u'type': u'executive'},
#   u'count': 18},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.telekom.com/investor_relations/corporate-governance/aufsichtsrat/26890'],
#    u'type': u'executive'},
#   u'count': 18},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.bayer.de/de/Mitglieder.aspx'],
#    u'type': u'executive'},
#   u'count': 18},
#  {u'_id': {u'end': {},
#    u'sources': [u'http://www.bmwi.de/BMWi/Redaktion/PDF/B/beiratsmitglieder-ttip,property=pdf,bereich=bmwi2012,sprache=de,rwb=true.pdf'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 18},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kreistages',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 18},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.deutsche-bank.de/de/content/company/Aufsichtsrat.htm'],
#    u'type': u'executive'},
#   u'count': 18},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 18},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2012},
#   u'count': 18},
#  {u'_id': {u'end': {},
#    u'sources': [u'http://www.amcham.de/members/member-lists/'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 17},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://deutsche-boerse.com/dbg/dispatch/de/kir/dbg_nav/investor_relations/15_Corporate_Governance/30_Supervisory_Board'],
#    u'type': u'executive'},
#   u'count': 17},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Gemeinderates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 17},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2012},
#   u'count': 17},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2011},
#   u'count': 17},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2010},
#   u'count': 17},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2004},
#   u'count': 17},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 17},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Parlamentarischen Beirates',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 17},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied im Verwaltungsrat',
#    u'sources': [u'http://www.swr.de/unternehmen/gremien/mitglieder-verwaltungsrat-swr-liste/-/id=12338976/did=13697116/nid=12338976/1dojz88/index.html'],
#    u'start': {},
#    u'type': u'member',
#    u'verified': True},
#   u'count': 16},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis', u'type': u'job'},
#   u'count': 16},
#  {u'_id': {u'amount': 25564.5,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2000},
#   u'count': 16},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Pr\xe4sident',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 16},
#  {u'_id': {u'amount': 25564.5,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1998},
#   u'count': 16},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1998},
#   u'count': 16},
#  {u'_id': {u'amount': 30000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 16},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1995},
#   u'count': 16},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2002},
#   u'count': 16},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://dgap.org/de/gesellschaft/mitgliedschaft'],
#    u'type': u'member'},
#   u'count': 15},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.merck.de/de/unternehmen/unternehmensfuehrung/super_visory_board/aufsichtsrat.html'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.henkel.de/unternehmen/management-und-gremien/henkel-aufsichtsrat'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'position': u'Mitglied des Stiftungsrats',
#    u'sources': [u'http://www.kulturstiftung.de/stiftung/struktur/stiftungsrat/'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://mslgroup.com'],
#    u'type': u'business'},
#   u'count': 15},
#  {u'_id': {u'activity': None,
#    u'desc': u'Entgeltliche T\xe4tigkeiten neben dem Mandat',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Gesch\xe4ftsf\xfchrer',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 15},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Stellv. Vorsitzender',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 15},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.sap.com/corporate-de/about/our-company/our-boards/supervisory-board.html'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 15},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2002},
#   u'count': 15},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.volkswagenag.com/content/vwcorp/content/de/investor_relations/corporate_governance/supervisory_board.html'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2010},
#   u'count': 15},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied der Verbandsversammlung',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 15},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2006},
#   u'count': 15},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.k-plus-s.com/de/aufsichtsrat/'],
#    u'type': u'executive'},
#   u'count': 15},
#  {u'_id': {u'end': {},
#    u'position': u'Ratsmitglied',
#    u'sources': [u'http://www.ecfr.eu/about/council#germany'],
#    u'start': {},
#    u'type': u'executive',
#    u'verified': True},
#   u'count': 15},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/Weber_Shandwick'],
#    u'type': u'business'},
#   u'count': 15},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1996},
#   u'count': 15},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.dvr.de/site/mitglieder.aspx'],
#    u'type': u'member'},
#   u'count': 14},
#  {u'_id': {u'position': u'Board of Directors',
#    u'sources': [u'http://www.amcham.de/about-us/board-of-directors.html'],
#    u'type': u'executive'},
#   u'count': 14},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Vorsitzender des Aufsichtsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 14},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1999},
#   u'count': 14},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 14},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.schroederschoembs.com'],
#    u'type': u'business'},
#   u'count': 14},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1sVup987wHu_jozH-X0mU6XZIJsUTkUjNijT0fgoBA6k/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 13},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'https://lobbypedia.de/wiki/Deekeling_Arndt_Advisors'],
#    u'type': u'job'},
#   u'count': 13},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'https://lobbypedia.de/wiki/Brunswick_Group'],
#    u'type': u'business'},
#   u'count': 13},
#  {u'_id': {u'desc': u'B\xfcndnis90/Die Gr\xfcnen',
#    u'position': u'Hausausweise',
#    u'type': u'pass'},
#   u'count': 13},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 13},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 13},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1999},
#   u'count': 13},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 13},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 13},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Advisory Councils',
#    u'sources': [u'https://www.securityconference.de/ueber-uns/advisory-council/'],
#    u'start': {},
#    u'type': u'executive',
#    u'verified': True},
#   u'count': 13},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2007},
#   u'count': 13},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2007},
#   u'count': 13},
#  {u'_id': {u'amount': 11000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 13},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Stiftungsrats',
#    u'sources': [u'http://www.swp-berlin.org/de/ueber-uns/organe-der-stiftung.html#mitglieder'],
#    u'start': {},
#    u'type': u'job',
#    u'verified': True},
#   u'count': 13},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'https://lobbypedia.de/wiki/Weber_Shandwick'],
#    u'type': u'job'},
#   u'count': 12},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'https://lobbypedia.de/wiki/WMP_Eurocom#Vorstand'],
#    u'type': u'job'},
#   u'count': 12},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.fppr.de'],
#    u'type': u'business'},
#   u'count': 12},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.fischerappelt.de'],
#    u'type': u'job'},
#   u'count': 12},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.infineon.com/cms/de/about-infineon/company/supervisory-board/'],
#    u'type': u'executive'},
#   u'count': 12},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1sVup987wHu_jozH-X0mU6XZIJsUTkUjNijT0fgoBA6k/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 12},
#  {u'_id': {u'amount': 13000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 12},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2006},
#   u'count': 12},
#  {u'_id': {u'amount': 20000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2002},
#   u'count': 12},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2000},
#   u'count': 12},
#  {u'_id': {u'amount': 30000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2012},
#   u'count': 12},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1995},
#   u'count': 12},
#  {u'_id': {u'amount': 12782.25,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1997},
#   u'count': 12},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2002},
#   u'count': 12},
#  {u'_id': {u'position': u'Vorstand',
#    u'sources': [u'http://www.bdi.eu/Vorstand.htm'],
#    u'type': u'executive'},
#   u'count': 12},
#  {u'_id': {u'end': {},
#    u'position': u'Hauptsponsor',
#    u'sources': [u'https://www.securityconference.de/ueber-uns/unterstuetzer-msc-2015/'],
#    u'start': {},
#    u'type': u'sponsoring',
#    u'verified': True},
#   u'count': 11},
#  {u'_id': {u'position': u'Staatssekret\xe4r',
#    u'start': {u'day': 18, u'month': 1, u'year': 2014},
#    u'type': u'government'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.heidelbergcement.com/de/Aufsichtsrat'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.beiersdorf.de/ueber-uns/unser-profil/aufsichtsrat'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.basf.com/de/company/about-us/management/supervisory-board.html'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://www.vfa.de/de/verband-mitglieder/mitgliedsunternehmen'],
#    u'type': u'member',
#    u'verified': True},
#   u'count': 11},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://www.bah-bonn.de/der-verband/unsere-mitglieder/'],
#    u'type': u'member'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.adidas-group.com/de/unternehmen/aufsichtsrat/'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'https://www.allianz.com/de/ueber_uns/management/aufsichtsrat/index.html#'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.the-linde-group.com/de/about_the_linde_group/management/supervisory_board/index.html'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'amount': 100000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 11},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2002},
#   u'count': 11},
#  {u'_id': {u'amount': 10500,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 11},
#  {u'_id': {u'amount': 12500,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 11},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.eon.com/de/investoren/corporate-governance/aufsichtsrat/mitglieder.html'],
#    u'type': u'executive'},
#   u'count': 11},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Pr\xe4sidiums',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 11},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.kmlz.de'],
#    u'type': u'job'},
#   u'count': 10},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://lobbypedia.de/wiki/APCO_Worldwide'],
#    u'type': u'business'},
#   u'count': 10},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.wuv.de/agenturen/adac_holt_cnc_communications_fuer_krisen_pr'],
#    u'type': u'job'},
#   u'count': 10},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://www.fresenius.de/88.htm'],
#    u'type': u'executive'},
#   u'count': 10},
#  {u'_id': {u'position': u'Vorstandsmitglied',
#    u'sources': [u'https://www.allianz.com/de/ueber_uns/management/vorstand/index.html#'],
#    u'type': u'executive'},
#   u'count': 10},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Stiftungsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 10},
#  {u'_id': {u'position': u'Aufsichtsratsmitglied',
#    u'sources': [u'http://lanxess.de/de/corporate/investor-relations/corporate-governance/aufsichtsrat/mitglieder/'],
#    u'type': u'executive'},
#   u'count': 10},
#  {u'_id': {u'activity': u'Rechtsanwalt',
#    u'desc': u'Entgeltliche T\xe4tigkeiten neben dem Mandat',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': None,
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 10},
#  {u'_id': {u'amount': 50000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 10},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1996},
#   u'count': 10},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2000},
#   u'count': 10},
#  {u'_id': {u'amount': 11000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 10},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2004},
#   u'count': 10},
#  {u'_id': {u'amount': 30000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 10},
#  {u'_id': {u'amount': 12500,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 10},
#  {u'_id': {u'amount': 30000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 10},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2003},
#   u'count': 10},
#  {u'_id': {u'position': u'Staatssekret\xe4r',
#    u'start': {u'day': 21, u'month': 6, u'year': 2012},
#    u'type': u'government'},
#   u'count': 10},
#  {u'_id': {u'position': u'Staatsrat',
#    u'start': {u'day': 23, u'month': 3, u'year': 2011},
#    u'type': u'government'},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Stellv. Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Senats',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 9},
#  {u'_id': {u'position': u'Botschafter',
#    u'sources': [u'http://www.insm.de/insm/ueber-die-insm/Kuratoren-und-Botschafter.html'],
#    u'type': u'job'},
#   u'count': 9},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Aufsichtsrats',
#    u'sources': [u'http://www.porsche-se.com/pho/de/porschese/administration/supervisoryboard/'],
#    u'start': {},
#    u'type': u'executive',
#    u'verified': True},
#   u'count': 9},
#  {u'_id': {u'amount': 10500,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Aufsichtsrates',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 9},
#  {u'_id': {u'amount': 15338.7,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2001},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Stellv. Vorsitzender',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 9},
#  {u'_id': {u'amount': 30000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 9},
#  {u'_id': {u'amount': 51129,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1998},
#   u'count': 9},
#  {u'_id': {u'amount': 51129,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2000},
#   u'count': 9},
#  {u'_id': {u'position': u'Mitglied', u'type': u'member', u'verified': True},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Vizepr\xe4sident',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 9},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Pr\xe4sident',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 9},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Aufsichtsrats',
#    u'sources': [u'http://www.porsche.com/germany/aboutporsche/overview/supervisoryboard/'],
#    u'start': {},
#    u'type': u'executive',
#    u'verified': True},
#   u'count': 8},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'position': u'Pers\xf6nliche Honorare f\xfcr Vortr\xe4ge',
#    u'sources': [u'http://www.akdae.de/Kommission/Organisation/Mitglieder/DoI/Laufs.pdf'],
#    u'type': u'business'},
#   u'count': 8},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.spiegel.de/spiegel/print/d-83422496.html'],
#    u'type': u'job'},
#   u'count': 8},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.ketchum.com'],
#    u'type': u'job'},
#   u'count': 8},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'sources': [u'http://www.lnegroup.eu/'],
#    u'type': u'business'},
#   u'count': 8},
#  {u'_id': {u'position': u'Arbeitsverh\xe4ltnis',
#    u'sources': [u'http://www.bohnen-kallmorgen.com/'],
#    u'type': u'job'},
#   u'count': 8},
#  {u'_id': {u'position': u'Vorstandsmitglied',
#    u'sources': [u'https://www.munichre.com/de/ir/shareholder-information/corporate-governance/board-of-management/index.html'],
#    u'type': u'executive'},
#   u'count': 8},
#  {u'_id': {u'desc': u'Gesch\xe4ftsverbindung',
#    u'position': u'Pers\xf6nliche Honorare f\xfcr Beratert\xe4tigkeit',
#    u'sources': [u'http://www.akdae.de/Kommission/Organisation/Mitglieder/DoI/Schwabe.pdf'],
#    u'type': u'business'},
#   u'count': 8},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'https://www.dwt-sgw.de/ueber-die-dwt/foerdernde-mitglieder/'],
#    u'type': u'member'},
#   u'count': 8},
#  {u'_id': {u'activity': None,
#    u'desc': u'Entgeltliche T\xe4tigkeiten neben dem Mandat',
#    u'end': {u'year': 2014},
#    u'level': 3,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': None,
#    u'start': {u'year': 2014},
#    u'unsalaried': False},
#   u'count': 8},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Vorstandes',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 8},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Unternehmen',
#    u'end': None,
#    u'level': 3,
#    u'periodical': u'j\xe4hrlich',
#    u'place': None,
#    u'position': u'Mitglied des Aufsichtsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 8},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Verwaltungsrates',
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 8},
#  {u'_id': {u'position': u'Vorstandsmitglied',
#    u'sources': [u'http://www.continental-corporation.com/www/portal_com_de/themen/continental/vors/vorstand/'],
#    u'type': u'executive'},
#   u'count': 8},
#  {u'_id': {u'position': u'Staatssekret\xe4r',
#    u'start': {u'day': 19, u'month': 4, u'year': 2011},
#    u'type': u'government'},
#   u'count': 8},
#  {u'_id': {u'amount': 10500,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 8},
#  {u'_id': {u'amount': 17000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2009},
#   u'count': 8},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in K\xf6rperschaften und Anstalten des \xf6ffentlichen Rechts',
#    u'end': None,
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Verwaltungsrates',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 8},
#  {u'_id': {u'amount': 15000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2004},
#   u'count': 8},
#  {u'_id': {u'amount': 12000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2008},
#   u'count': 8},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bdsi.de/der-verband/mitglieder/unsere-mitglieder/'],
#    u'type': u'member'},
#   u'count': 8},
#  {u'_id': {u'amount': 13000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2005},
#   u'count': 8},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2011},
#   u'count': 8},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2010},
#   u'count': 8},
#  {u'_id': {u'amount': 20451.6,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 1998},
#   u'count': 8},
#  {u'_id': {u'amount': 13000,
#    u'sources': [u'https://docs.google.com/spreadsheets/d/1caESI467tBJ8uwv0RqjI-3AJYYcrdceJhfRPAtm2yXw/edit?usp=sharing'],
#    u'year': 2013},
#   u'count': 8},
#  {u'_id': {u'amount': 25000,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2006},
#   u'count': 8},
#  {u'_id': {u'end': {},
#    u'position': u'Mitglied des Aufsichtsrats',
#    u'sources': [u'http://www.bertelsmann.de/unternehmen/aufsichtsrat/#st-1'],
#    u'start': {},
#    u'type': u'job',
#    u'verified': True},
# ...
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hupach_sigrid/258470'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/huber_charles/259332'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hornhues_bettina/259440'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/horb_margaret/258438'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/K/klein_volkmar/258598'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/holmeier_karl/258454'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hirte_heribert/258444'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/heveling_ansgar/258472'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/J/jung_franz_josef/258540'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/held_marcus.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/heinrich_gabriela.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/heidenblut_dirk.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hauer_matthias/259374'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/V/viesehon_thomas/259302'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hampel_ulrich.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hakverdi_metin.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hahn_andre/258442'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hahn_florian/258512'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/haase_christian/258520'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/gutting_olav/258380'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/grund_manfred/258374'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/gruebel_markus/258414'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/groetsch_uli.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied', u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/gross_michael.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/T/tank_azize/259422'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.ipv.de/fileadmin/user_upload/PDF/Daniel_Bahr.pdf'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/-/340584'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/gienger_eberhard/258430'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'activity': u'Rechtsanwalt',
#    u'desc': u'Entgeltliche T\xe4tigkeiten neben dem Mandat',
#    u'end': {u'year': 2014},
#    u'level': 6,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': None,
#    u'start': {u'year': 2014},
#    u'unsalaried': False},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/fuchs_michael/258340'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/frei_thorsten/258354'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/fograscher_gabriele.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/freese_ulrich.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'activity': u'Rechtsanwalt',
#    u'desc': u'Entgeltliche T\xe4tigkeiten neben dem Mandat',
#    u'end': None,
#    u'level': 1,
#    u'periodical': u'monatlich',
#    u'place': None,
#    u'position': None,
#    u'start': None,
#    u'unsalaried': False},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/L/liebing_ingbert/258718'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/L/laemmel_andreas/258684'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/ferner_elke.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/feist_thomas/258326'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/fechner_johannes.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/fechner_johannes.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/E/erler_gernot.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/E/eckenbach_jutta/259442'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/D/durz_hans_joerg/258274'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/E/ebner_harald/258316'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/G/gaedechens_ingo/258400'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/D/doerflinger_thomas/258276'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/D/donth_michael/258282'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/D/diaby_karamba.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/R/rohde_dennis.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/D/daldrup_bernhard.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/J/jantz_christina.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/R/rueddel_erwin/258922'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/F/feiler_uwe/258322'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brunner_karlheinz.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brehmer_heike/258232'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brinkhaus_ralph/258184'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brase_willi.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brand_michael/258188'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/brackmann_norbert/258152'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/blienert_burkhard.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/R/rimkus_andreas.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/beyer_peter/258200'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/bertram_ute/259406'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/berghegger_andre/258176'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/behrens_herbert/258180'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/beermann_maik/259310'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Stellvertretendes Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/heil_hubertus.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/beermann_maik/259310'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/bas_baerbel.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'activity': None,
#    u'desc': u'Funktionen in Vereinen, Verb\xe4nden und Stiftungen',
#    u'end': {u'day': 28, u'month': 2, u'year': 2014},
#    u'level': 0,
#    u'periodical': u'einmalig',
#    u'place': None,
#    u'position': u'Mitglied des Kuratoriums',
#    u'start': None,
#    u'unsalaried': True},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/bareiss_thomas/258236'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/baerbock_annalena/258202'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/A/auernhammer_artur/258140'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/E/esken_saskia.html'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/A/aken_jan/258124'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/K/koenigs_tom/258568'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/I/irlstorfer_erich/258530'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hahn_florian/258512'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/W/wellenreuther_ingo/259208'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/H/hoppenstedt_hendrik/259328'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/C/caesar_cajus/258254'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/K/kuehn_christian/258590'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'amount': 11500,
#    u'sources': [u'http://apps.opendatacity.de/parteispenden-recherche/assets/data/parteispenden.json'],
#    u'year': 2011},
#   u'count': 3},
#  {u'_id': {u'position': u'Ordentliches Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/B/bilger_steffen/258230'],
#    u'type': u'member'},
#   u'count': 3},
#  {u'_id': {u'position': u'Mitglied',
#    u'sources': [u'http://www.bundestag.de/bundestag/abgeordnete18/biografien/Z/zimmermann_jens.html'],
#    u'type': u'member'},
#   u'count': 3},
#  ...]
